# %% [markdown]
# # Inferential statistics
# ## Part II - Exploratory Data Analysis
#
# Before starting the actual analysis it's a good idea to explore the data that we will be using, to give yourself a first idea of the questions you will be able to answer with your data, the bias you could have, other data you could need, etc.
#
# ### Libraries
# In addition to pandas we will also import matplolib and seaborn so that we will able to plot our data to better understand it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Explore the dataset
#
# Let's load the cleaned dataset first. Import it with the name `wnba` and show the head.

# %%
#your code here

wnba = pd.read_csv("../data/wnba_clean.csv")

# %% [markdown]
# **Use describe() to take an initial look at the data.**

# %%
#your code here

wnba.describe()
# Out:
#            Height      Weight         BMI         Age  Games Played  \
# count  142.000000  142.000000  142.000000  142.000000    142.000000
# mean   184.612676   78.978873   23.091214   27.112676     24.429577
# std      8.698128   10.996110    2.073691    3.667180      7.075477
# min    165.000000   55.000000   18.390675   21.000000      2.000000
# 25%    175.750000   71.500000   21.785876   24.000000     22.000000
# 50%    185.000000   79.000000   22.873314   27.000000     27.500000
# 75%    191.000000   86.000000   24.180715   30.000000     29.000000
# max    206.000000  113.000000   31.555880   36.000000     32.000000
#
#                MIN         FGM         FGA         FG%         3PM  \
# count   142.000000  142.000000  142.000000  142.000000  142.000000
# mean    500.105634   74.401408  168.704225   43.102817   14.830986
# std     289.373393   55.980754  117.165809    9.855199   17.372829
# min      12.000000    1.000000    3.000000   16.700000    0.000000
# ...

# %% [markdown]
# Most of the game-related stats have a very high range of values which can be explained by the fact that the dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# There are also some extremes in the weight and age columns. Feel free, if you'd like, to check which are the players with a very high (or low) age/weight and do some research on them. This is useful to confirm that they are simply outliers and not errors in the data.

# %%
#your code here

high_age_extremes = wnba[wnba['Age'] > wnba['Age'].quantile(0.95)]

low_age_extremes = wnba[wnba['Age'] < wnba['Age'].quantile(0.05)]

high_age_extremes.head()
# Out:
#                  Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 1         Alana Beard   LA  G/F     185      73  21.329438          US
# 67        Jia Perkins  MIN    G     173      75  25.059307          US
# 105  Plenette Pierson  MIN  F/C     188      88  24.898144          US
# 109  Rebekkah Brunson  MIN    F     188      84  23.766410          US
# 126          Sue Bird  SEA    G     175      68  22.204082          US
#
#              Birthdate  Age      College Experience  Games Played  MIN  FGM  \
# 1         May 14, 1982   35         Duke         12            30  947   90
# 67   February 23, 1982   35   Texas Tech         14            30  932  178
# 105    August 31, 1981   35   Texas Tech         15            29  402   54
# 109  November 12, 1981   35   Georgetown         14            26  719   97
# 126   October 16, 1980   36  Connecticut         15            27  806  103
#
#      FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  DREB  REB  AST  STL  \
# ...

# %%
low_age_extremes.head()
# Out:
#               Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 15  Angel Robinson  PHO  F/C     198      88  22.446689          US
# 23   Brionna Jones  CON    F     191     104  28.507990          US
#
#             Birthdate  Age        College Experience  Games Played  MIN  FGM  \
# 15    August 30, 1995   21  Arizona State          1            15  237   25
# 23  December 18, 1995   21       Maryland          R            19  112   14
#
#     FGA   FG%  3PM  3PA    3P%  FTM  FTA    FT%  OREB  DREB  REB  AST  STL  \
# 15   44  56.8    1    1  100.0    7    7  100.0    16    42   58    8    1
# 23   26  53.8    0    0    0.0   16   19   84.2    11    14   25    2    7
#
#     BLK  TO  PTS  DD2  TD3
# 15   11  16   58    0    0
# 23    1   7   44    0    0

# %%
high_weight_extremes = wnba[wnba['Weight'] > wnba['Weight'].quantile(0.95)]

low_weight_extremes = wnba[wnba['Weight'] < wnba['Weight'].quantile(0.05)]

high_weight_extremes.head()
# Out:
#                 Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 12   Amanda Zahui B.   NY    C     196     113  29.414827          SE
# 23     Brionna Jones  CON    F     191     104  28.507990          US
# 36    Courtney Paris  DAL    C     193     113  30.336385          US
# 41    Danielle Adams  CON  F/C     185     108  31.555880          US
# 84  Lanay Montgomery  SEA    C     196      96  24.989588          US
#
#              Birthdate  Age        College Experience  Games Played  MIN  FGM  \
# 12      August 9, 1993   24      Minnesota          3            25  133   20
# 23   December 18, 1995   21       Maryland          R            19  112   14
# 36  September 21, 1987   29       Oklahoma          7            16  217   32
# 41   February 19, 1989   28      Texas A&M          5            18   81   16
# 84  September 17, 1993   23  West Virginia          R             7   28    3
#
# ...

# %%
low_weight_extremes.head()
# Out:
#                  Name Team Pos  Height  Weight        BMI Birth_Place  \
# 38  Courtney Williams  CON   G     173      62  20.715694          US
# 42  Danielle Robinson  PHO   G     175      57  18.612245          US
# 82     Kristi Toliver  WAS   G     170      59  20.415225          US
# 86   Leilani Mitchell  PHO   G     165      58  21.303949          US
# 96   Moriah Jefferson  SAN   G     168      55  19.486961          US
#
#            Birthdate  Age        College Experience  Games Played  MIN  FGM  \
# 38  November 5, 1994   22  South Florida          1            29  755  168
# 42   October 5, 1989   27       Oklahoma          7            28  680   79
# 82  January 27, 1987   30       Maryland          9            29  845  119
# 86     June 15, 1985   32           Utah          9            30  623   70
# 96    August 3, 1994   23    Connecticut          1            21  514   81
#
#     FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  \
# ...

# %% [markdown]
# ### Looking at the distributions of the data
# Let's take a look at the distribution of the 4 stats that describe the physical characteristics of the players.
#
# **Plot the four distributions about `height`, `weight`, `age` and `BMI`.**

# %%
#your code here

import matplotlib.pyplot as plt


fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Plotting the distribution of Height
axes[0, 0].hist(wnba['Height'], bins=20, color='skyblue', edgecolor='black')
axes[0, 0].set_title('Distribution of Height')

# Plotting the distribution of Weight
axes[0, 1].hist(wnba['Weight'], bins=20, color='lightgreen', edgecolor='black')
axes[0, 1].set_title('Distribution of Weight')

# Plotting the distribution of Age
axes[1, 0].hist(wnba['Age'], bins=20, color='salmon', edgecolor='black')
axes[1, 0].set_title('Distribution of Age')

# Plotting the distribution of BMI
axes[1, 1].hist(wnba['BMI'], bins=20, color='gold', edgecolor='black')
axes[1, 1].set_title('Distribution of BMI')


plt.tight_layout()

plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here

#Distribution of Height: multi-modal, with several peaks, 
#which suggests that there are clusters of players at certain heights.
#There is a significant presence of players in the height range around 180 cm to 190 cm.

#Distribution of Weight: slightly right-skewed, with a concentration of players in the 70-90 kg range.
# not so much in the lower range (below 60 kg) or higher range (above 100 kg), indicating that most WNBA players have a weight that falls within a relatively narrow range suited for their sport.

#Distribution of Age: relatively uniform between ages 24 and 30, with fewer players below 24 and above 30.
#This might reflect a typical career span in the WNBA.

#Distribution of BMI: normally distributed with a slight right skew.
#Most players have a BMI in the range considered normal or healthy, which aligns with the expectations for professional athletes.

# %% [markdown]
# In addition to what the describe() method already told us we can see that the physical characteristics of the players (apart from the age) more or less follow a standard distribution, which is expected when looking at the distribution of values that arise from a lot of factors that are independent from each other as is the case for many physical quantities.
#
# The height distribution looks like a bimodal. This may be due to the fact that players in basketball fall under two main categories (please note that this is a very gross generalization): shorter and more agile, and taller and less agile. Therefore there are less "average" height players since they will neither be as agile as the shorter players nor have the same impact in the paint (that is, under the basket) as a taller player.
#
# The age distribution is a bit skewed to the right which is expected since most professional players stop playing after their prime physical years come to an end.

# %% [markdown]
# We could do the same for the main game stats. They are points, assists, blocks, rebounds and steals.
#
# **Now plot the distribution of the columns `REB`, `AST`, `STL`, `PTS` and `BLK` the same way you did in the last cell.**

# %%
#your code here

fig, axes = plt.subplots(3, 2, figsize=(10, 15))

# Plotting the distribution of Rebounds
axes[0, 0].hist(wnba['REB'], bins=20, color='purple', edgecolor='black')
axes[0, 0].set_title('Distribution of Rebounds')

# Plotting the distribution of Assists
axes[0, 1].hist(wnba['AST'], bins=20, color='orange', edgecolor='black')
axes[0, 1].set_title('Distribution of Assists')

# Plotting the distribution of Steals
axes[1, 0].hist(wnba['STL'], bins=20, color='green', edgecolor='black')
axes[1, 0].set_title('Distribution of Steals')

# Plotting the distribution of Points
axes[1, 1].hist(wnba['PTS'], bins=20, color='blue', edgecolor='black')
axes[1, 1].set_title('Distribution of Points')

# Plotting the distribution of Blocks
axes[2, 0].hist(wnba['BLK'], bins=20, color='red', edgecolor='black')
axes[2, 0].set_title('Distribution of Blocks')


plt.tight_layout()


fig.delaxes(axes[2][1])


plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here

#Rebounds (REB): most players gather a moderate number of rebounds, 
#with a significant drop as the number increases, which is typical since not all players are in roles or positions that facilitate high rebounding numbers.

#Assists (AST):
#A large number of players have a relatively low number of assists, 
#with the frequency decreasing sharply as the number of assists increases. 
#This suggests that high assist totals may be confined to players with specific roles, such as point guards or those with playmaking responsibilities.

#Steals (STL):
#Steals are generally less common statistical achievements, as reflected by the high frequency of lower numbers and rapid decrease in frequency as the number of steals increases. This indicates that steals are a relatively rarer event in the game compared to other statistics.

#Points (PTS):
#The distribution of points scored is right-skewed, with a high frequency of players scoring fewer points and a gradual decrease in frequency as points increase. There are fewer players scoring very high points, highlighting the difference between average scorers and standout offensive players.

#Blocks (BLK):
#Blocks are a rare statistical event. Most players have very few blocks, with the numbers dropping off quickly. This is consistent with the nature of the block, which is a specialized defensive play typically made by a few players with specific physical attributes and roles.

# %% [markdown]
# As expected all of the above distribution are heavily skewed to the right, since most players will have very low to average stats while there will be a handful of star players whose stats peak above everyone else. It is also important to think about the fact that we are simply taking the stats as they are without considering the minutes played by each player. Even though skill plays a very important factor in determining this kind of stats we also have to consider that players that play more minutes will, on average, score more points (or blocks, assists, etc.).

# %% [markdown]
# **For the sake of it let's look at the same distributions by dividing those stats by the minutes played for each player in the dataset.**

# %%
#your code here

wnba['REB_per_MIN'] = wnba['REB'] / wnba['MIN']
wnba['AST_per_MIN'] = wnba['AST'] / wnba['MIN']
wnba['STL_per_MIN'] = wnba['STL'] / wnba['MIN']
wnba['PTS_per_MIN'] = wnba['PTS'] / wnba['MIN']
wnba['BLK_per_MIN'] = wnba['BLK'] / wnba['MIN']


fig, axes = plt.subplots(5, 1, figsize=(10, 18)) 

# Plotting the distribution of Rebounds per Minute
axes[0].hist(wnba['REB_per_MIN'].dropna(), bins=20, color='purple', edgecolor='black')
axes[0].set_title('Distribution of Rebounds per Minute')

# Plotting the distribution of Assists per Minute
axes[1].hist(wnba['AST_per_MIN'].dropna(), bins=20, color='orange', edgecolor='black')
axes[1].set_title('Distribution of Assists per Minute')

# Plotting the distribution of Steals per Minute
axes[2].hist(wnba['STL_per_MIN'].dropna(), bins=20, color='green', edgecolor='black')
axes[2].set_title('Distribution of Steals per Minute')

# Plotting the distribution of Points per Minute
axes[3].hist(wnba['PTS_per_MIN'].dropna(), bins=20, color='blue', edgecolor='black')
axes[3].set_title('Distribution of Points per Minute')

# Plotting the distribution of Blocks per Minute
axes[4].hist(wnba['BLK_per_MIN'].dropna(), bins=20, color='red', edgecolor='black')
axes[4].set_title('Distribution of Blocks per Minute')

plt.tight_layout()
plt.show()

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here

# %% [markdown]
# ### Summary
#
# The main insights we obtained from this exploratory analysis are:
# - Game-related stats have a very high range of values.
# - There are some extremes in the weight and age columns.
# - The physical characteristics of the players more or less follow a standard distribution.
# - We need to take into account that our dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# Now, it's time to try to put an end to your family's discussions. As seen on the README, the main discussions are:
# - Your grandmother says that your sister couldn't play in a professional basketball league (not only the WNBA, but ANY professional basketball league) because she's too skinny and lacks muscle.
# - Your sister says that most female professional players fail their free throws.
# - Your brother-in-law heard on the TV that the average assists among NBA (male) and WNBA (female) players is 52 for the 2016-2017 season. He is convinced this average would be higher if we only considered the players from the WNBA.
#
# **Do you think you have all the necessary data to answer these questions?**

# %%
#your comments here

# Yes we have enough data the answer these questions, except for the 3rd one


# For Grandmother's claim: Analyze physical attributes
average_height = wnba['Height'].mean()
average_weight = wnba['Weight'].mean()
average_BMI = wnba['BMI'].mean()
# Compare these averages to the sister's measurements.

# For Sister's claim: Calculate average FT%
average_FT_percentage = (wnba['FTM'].sum() / wnba['FTA'].sum()) * 100

# For Brother-in-law's claim: Calculate average assists
average_assists = wnba['AST'].mean()
# To compare with NBA, we would need to obtain NBA data for the 2016-2017 season.

print((round(average_FT_percentage, 2), round(average_assists, 2)))
#average FT percentage for wnba is very good
# Out:
# (79.99, 44.51)
